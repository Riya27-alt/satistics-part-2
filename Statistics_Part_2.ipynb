# %% [markdown]
# Statistics theory qustions
# 1. What is hypothesis testing in statistics?
# Hypothesis testing is a method to make decisions or inferences about a population based on sample data. It helps determine whether an observed effect is statistically significant or just due to chance.
#
# 2. What is the null hypothesis and how does it differ from the alternative hypothesis?
# Null Hypothesis (H₀): Assumes no effect or no difference (e.g., "There is no difference between group A and B").
#
# Alternative Hypothesis (H₁ or Ha): Assumes there is an effect or a difference.
#
# 3.  What is the significance level in hypothesis testing, and why is it important?
# The significance level (α) is the probability of rejecting the null hypothesis when it's actually true.
#
# Common values: 0.05, 0.01.
#
# It sets the threshold for what is considered statistically significant.
#
# 4. What does a P-value represent in hypothesis testing?
# The P-value is the probability of getting the observed result (or more extreme) if the null hypothesis is true.
#
# 5. How do you interpret the P-value in hypothesis testing?
# If P ≤ α, reject the null hypothesis (result is significant).
#
# If P > α, fail to reject the null (result is not significant).
#
# 6. What are Type I and Type II errors?
# Type I Error (False Positive): Rejecting a true null hypothesis.
#
# Type II Error (False Negative): Failing to reject a false null hypothesis.
#
# 7. Difference between one-tailed and two-tailed tests:
# One-tailed test: Looks for an effect in one direction.
#
# Two-tailed test: Tests for any difference (either direction).
#
# 8. What is the Z-test, and when is it used?
# Used when:
#
# The population variance is known.
#
# Sample size is large (n > 30).
#
# Data is normally distributed.
#
# 9. How do you calculate the Z-score and what does it represent?
# 𝑍
# =
# (
# 𝑋
# −
# 𝜇
# )
# 𝜎
# Z=
# σ
# (X−μ)
# ​
#
#
# Measures how many standard deviations a value is from the mean.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
# Used when:
#
# The population variance is unknown.
#
# Sample size is small (n < 30).
#
# 11. Difference between a Z-test and a T-test:
# Z-test: Known population standard deviation.
#
# T-test: Unknown population standard deviation.
#
# 12. What is the T-test, and how is it used?
# Tests if the means of two groups are significantly different. Types include:
#
# One-sample
#
# Independent two-sample
#
# Paired sample
#
# 13. Relationship between Z-test and T-test:
# Both are used for comparing means, but Z-test uses the normal distribution while T-test uses the t-distribution (especially with smaller samples).
#
# 14. What is a confidence interval and how is it used?
# It gives a range of values likely to contain the population parameter. A 95% confidence interval means we are 95% confident that the true value lies in this range.
#
# 15. What is the margin of error and how does it affect the confidence interval?
# The margin of error is the range added/subtracted from the sample estimate to create the confidence interval. A larger margin = wider interval.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
# Bayes' Theorem updates the probability of a hypothesis based on new evidence. It is widely used in diagnostic testing and decision making.
#
# 17. What is the Chi-square distribution, and when is it used?
# Used for categorical data to test relationships or goodness of fit between observed and expected frequencies.
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
# It tests if a sample matches an expected distribution. Example: testing if a die is fair.
#
# 19. What is the F-distribution, and when is it used?
# Used in ANOVA and F-tests to compare variances across groups.
#
# 20. What is an ANOVA test, and what are its assumptions?
# ANOVA (Analysis of Variance) compares the means of 3 or more groups. Assumptions:
#
# Normal distribution
#
# Equal variances
#
# Independent samples
#
# 21. What are the different types of ANOVA tests?
# One-way ANOVA: One independent variable.
#
# Two-way ANOVA: Two independent variables.
#
# Repeated Measures ANOVA: Same subjects measured multiple times.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
# It compares variances. Used in ANOVA to check if group variances are significantly different.

# %% [markdown]
# Practical Part 1

# %%
import random
value = random.randint(1, 100)
print("Random variable value:", value)
# Out:
# Random variable value: 100

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import randint

x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)  # Discrete uniform from 1 to 6
plt.bar(x, pmf)
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.show()

# %%
from scipy.stats import bernoulli

def bernoulli_pdf(p):
    return [bernoulli.pmf(0, p), bernoulli.pmf(1, p)]

print("PDF:", bernoulli_pdf(0.5))
# Out:
# PDF: [np.float64(0.5000000000000001), np.float64(0.5)]

# %%
import matplotlib.pyplot as plt
import numpy as np

n, p = 10, 0.5
data = np.random.binomial(n, p, 1000)
plt.hist(data, bins=np.arange(n+2)-0.5, edgecolor='black')
plt.title("Binomial Distribution Histogram")
plt.xlabel("Successes")
plt.ylabel("Frequency")
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

mu = 3
x = np.arange(0, 10)
pmf = poisson.pmf(x, mu)
plt.bar(x, pmf)
plt.title("Poisson Distribution (mu = 3)")
plt.xlabel("k")
plt.ylabel("P(X = k)")
plt.show()

# %%
cdf = randint.cdf(x, 1, 7)
plt.step(x, cdf, where="post")
plt.title("CDF of Discrete Uniform Distribution")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.show()

# %%
from scipy.stats import uniform

data = uniform.rvs(size=1000)
plt.hist(data, bins=30, density=True)
plt.title("Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
data = np.random.normal(loc=0, scale=1, size=1000)
plt.hist(data, bins=30, density=True)
plt.title("Normal Distribution Histogram")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
from scipy.stats import zscore

data = np.random.normal(100, 15, size=100)
z_scores = zscore(data)
plt.hist(z_scores, bins=30)
plt.title("Z-score Distribution")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.random.exponential(scale=2.0, size=10000)
sample_means = [np.mean(np.random.choice(population, size=30)) for _ in range(1000)]

plt.hist(sample_means, bins=30, density=True)
plt.title("CLT: Distribution of Sample Means (Exponential Dist.)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.show()

# %%
from scipy.stats import norm

x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x)
plt.plot(x, pdf)
plt.title("Standard Normal Distribution")
plt.xlabel("Z")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
n, p = 10, 0.5
x = np.arange(0, n+1)
prob = binom.pmf(x, n, p)

plt.bar(x, prob)
plt.title("Binomial PMF")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a452a1bc5673> in <cell line: 0>()
#       1 n, p = 10, 0.5
#       2 x = np.arange(0, n+1)
# ----> 3 prob = binom.pmf(x, n, p)
#       4
#       5 plt.bar(x, prob)
#
# NameError: name 'binom' is not defined

# %%
def calculate_z(x, mu, sigma):
    return (x - mu) / sigma

z = calculate_z(75, mu=70, sigma=10)
print("Z-score:", z)
# Out:
# Z-score: 0.5

# %%
sample_mean = 72
population_mean = 70
std_dev = 10
n = 30

z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
print("Z-statistic:", z)
# Out:
# Z-statistic: 1.0954451150103321

# %%
import scipy.stats as stats

data = np.random.normal(50, 10, 100)
mean = np.mean(data)
sem = stats.sem(data)
conf_int = stats.t.interval(0.95, len(data)-1, loc=mean, scale=sem)
print("95% Confidence Interval:", conf_int)
# Out:
# 95% Confidence Interval: (np.float64(48.11230652828956), np.float64(51.95847487243645))

# %%
data = np.random.normal(60, 12, 100)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.t.interval(0.95, df=len(data)-1, loc=mean, scale=sem)
print("Confidence Interval for Mean:", ci)
# Out:
# Confidence Interval for Mean: (np.float64(56.44317798797424), np.float64(61.612214086370216))

# %%
x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x)
plt.plot(x, pdf)
plt.title("PDF of Normal Distribution")
plt.xlabel("x")
plt.ylabel("Density")
plt.show()

# %%
x = np.arange(0, 10)
cdf = poisson.cdf(x, mu=3)
plt.step(x, cdf, where='post')
plt.title("CDF of Poisson Distribution (mu = 3)")
plt.xlabel("k")
plt.ylabel("Cumulative Probability")
plt.show()

# %%
data = uniform.rvs(loc=0, scale=1, size=1000)
expected_value = np.mean(data)
print("Expected Value:", expected_value)
# Out:
# Expected Value: 0.49442091711823744

# %%
data1 = np.random.normal(50, 5, 100)
data2 = np.random.normal(50, 15, 100)

std1 = np.std(data1)
std2 = np.std(data2)

plt.boxplot([data1, data2], labels=['Set 1', 'Set 2'])
plt.title("Comparison of Standard Deviations")
plt.show()

print("Std Dev 1:", std1, "Std Dev 2:", std2)
# Out:
# <ipython-input-25-75c7508bef3d>:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Set 1', 'Set 2'])
# Std Dev 1: 5.017349022356033 Std Dev 2: 12.338063674669527

# %%
data = np.random.normal(0, 1, 1000)
range_val = np.ptp(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print("Range:", range_val)
print("IQR:", iqr)

# %%
data = np.random.normal(100, 20, 1000)
normalized = zscore(data)

plt.hist(normalized, bins=30)
plt.title("Z-score Normalized Data")
plt.show()

# %%
from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.02986423656509182
# Kurtosis: -0.1745718931732565

# %% [markdown]
# Practical part 2

# %%
from scipy.stats import norm
import numpy as np

sample = np.random.normal(105, 10, 30)
population_mean = 100
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

z = (sample_mean - population_mean) / (sample_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print("Z-statistic:", z)
print("P-value:", p_value)
# Out:
# Z-statistic: 1.402097022922727
# P-value: 0.1608862759683749

# %%
np.random.seed(0)
data = np.random.normal(100, 15, 50)
mean = np.mean(data)
z = (mean - 100) / (15 / np.sqrt(50))
p = 2 * (1 - norm.cdf(abs(z)))

print("Simulated Mean:", mean)
print("Z-score:", z)
print("P-value:", p)
# Out:
# Simulated Mean: 102.10838908469648
# Z-score: 0.9939041461123878
# P-value: 0.3202695356659744

# %%
def one_sample_z_test(sample, population_mean, pop_std):
    n = len(sample)
    sample_mean = np.mean(sample)
    z = (sample_mean - population_mean) / (pop_std / np.sqrt(n))
    p = 2 * (1 - norm.cdf(abs(z)))
    return z, p

sample = np.random.normal(102, 10, 40)
z, p = one_sample_z_test(sample, 100, 10)
print("Z-statistic:", z, "P-value:", p)
# Out:
# Z-statistic: 0.24672790174905082 P-value: 0.8051188115134582

# %%
import matplotlib.pyplot as plt

z_crit = norm.ppf(0.975)  # 95% CI
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y)
plt.fill_between(x, y, where=(x < -z_crit) | (x > z_crit), color='red', alpha=0.3)
plt.axvline(z, color='blue', linestyle='--', label=f'Z = {z:.2f}')
plt.title("Two-Tailed Z-test Decision Region")
plt.legend()
plt.show()

# %%
def plot_type1_type2(alpha=0.05, beta=0.2):
    x = np.linspace(-4, 4, 1000)
    null = norm.pdf(x, 0, 1)
    alt = norm.pdf(x, 1.5, 1)

    plt.plot(x, null, label='H0', color='blue')
    plt.plot(x, alt, label='H1', color='green')
    plt.fill_between(x, null, where=(x > norm.ppf(1 - alpha)), color='red', alpha=0.3, label='Type I Error')
    plt.fill_between(x, alt, where=(x < norm.ppf(1 - alpha)), color='orange', alpha=0.3, label='Type II Error')
    plt.legend()
    plt.title("Type I and Type II Errors")
    plt.show()

plot_type1_type2()

# %%
from scipy.stats import ttest_ind

group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)

t_stat, p_val = ttest_ind(group1, group2)
print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: -0.340298406170199
# P-value: 0.7348612591632302

# %%
from scipy.stats import ttest_rel

before = np.random.normal(70, 5, 20)
after = before + np.random.normal(2, 3, 20)

t_stat, p_val = ttest_rel(before, after)
plt.boxplot([before, after], labels=["Before", "After"])
plt.title("Paired Sample Comparison")
plt.show()

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# <ipython-input-32-e198311b1e17>:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([before, after], labels=["Before", "After"])
# T-statistic: -1.566824333118244
# P-value: 0.13365952499349915

# %%
from scipy.stats import ttest_1samp

data = np.random.normal(100, 15, 25)
z_stat = (np.mean(data) - 100) / (15 / np.sqrt(len(data)))
t_stat, p_val = ttest_1samp(data, 100)

print("Z-test:", z_stat)
print("T-test:", t_stat, "P-value:", p_val)
# Out:
# Z-test: 0.6810842556546911
# T-test: 0.768827056464978 P-value: 0.44949616657397606

# %%
def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    sem = stats.sem(data)
    interval = stats.t.interval(confidence, len(data)-1, loc=mean, scale=sem)
    return interval

sample = np.random.normal(50, 8, 40)
ci = confidence_interval(sample)
print("Confidence Interval:", ci)
# Out:
# Confidence Interval: (np.float64(46.532226029611365), np.float64(51.08005458646973))

# %%
def margin_of_error(data, confidence=0.95):
    sem = stats.sem(data)
    moe = sem * stats.t.ppf((1 + confidence) / 2., len(data)-1)
    return moe

sample = np.random.normal(60, 12, 30)
print("Margin of Error:", margin_of_error(sample))
# Out:
# Margin of Error: 5.012329765755102

# %%
def bayes_theorem(p_A, p_B_given_A, p_B_given_not_A):
    p_not_A = 1 - p_A
    p_B = p_B_given_A * p_A + p_B_given_not_A * p_not_A
    p_A_given_B = (p_B_given_A * p_A) / p_B
    return p_A_given_B

# Example: Disease test
print("P(Disease | Positive Test):", bayes_theorem(0.01, 0.99, 0.05))
# Out:
# P(Disease | Positive Test): 0.16666666666666669

# %%
import pandas as pd
from scipy.stats import chi2_contingency

data = [[30, 10], [20, 40]]  # Contingency Table
chi2, p, dof, expected = chi2_contingency(data)
print("Chi-square Statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square Statistic: 15.041666666666666
# P-value: 0.00010516355403363098

# %%
observed = np.array([[50, 30], [20, 100]])
_, _, _, expected = chi2_contingency(observed)
print("Expected Frequencies:\n", expected)
# Out:
# Expected Frequencies:
#  [[28. 52.]
#  [42. 78.]]

# %%
from scipy.stats import chisquare

observed = [25, 35, 40]
expected = [33.3, 33.3, 33.3]
chi2_stat, p = chisquare(f_obs=observed, f_exp=expected)

print("Chi-square Statistic:", chi2_stat)
print("P-value:", p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-bd72e4cb4bbb> in <cell line: 0>()
#       3 observed = [25, 35, 40]
#       4 expected = [33.3, 33.3, 33.3]
# ----> 5 chi2_stat, p = chisquare(f_obs=observed, f_exp=expected)
#       6
#       7 print("Chi-square Statistic:", chi2_stat)
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_stats_py.py in chisquare(f_obs, f_exp, ddof, axis, sum_check)
#    7504     For a more detailed example, see :ref:`hypothesis_chisquare`.
#    7505     """  # noqa: E501
# -> 7506     return _power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    7507                              lambda_="pearson", sum_check=sum_check)
#    7508
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_stats_py.py in _power_divergence(f_obs, f_exp, ddof, axis, lambda_, sum_check)
# ...
